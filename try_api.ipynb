# %%
api_key =  "DhDkXZkGXaYBZhkk1Z9m9BuZDJGy"
import json
import requests

# %%
hotel_group_types = 'basic'

url = f"https://k6oayrgulgb5sasvwj3tsy7l7u0tikfd.lambda-url.ap-northeast-1.on.aws/api/v3/tools/interview_test/taiwan_hotels/hotels?hotel_group_types={hotel_group_types}"

headers = {
    "accept": "application/json",
    "Authorization": "DhDkXZkGXaYBZhkk1Z9m9BuZDJGy"
}

response = requests.get(url, headers=headers)
response.json()
# Out:
# [{'id': 25,
#   'status': 'OPEN',
#   'domain': 'checkinnselecttng',
#   'name': '雀客藏居台北南港',
#   'phone': '0226 512 251',
#   'meals': None,
#   'url': 'https://www.mastripms.com/checkinnselecttng/view',
#   'check_in': '15:00:00',
#   'last_check_in': '23:59:00',
#   'check_out': '11:00:00',
#   'service_mail': 'reservation.service@dunqian.com',
#   'child_age': 12,
#   'address': '115台北市南港區重陽路59號 No. 59, Chongyang Road, Nangang District, Taipei City 115, Taiwan (R.O.C.)',
#   'latitude': 25.05591,
#   'longitude': 121.59671,
#   'intro': '旅行的重頭戲在於找到一個舒適的夜間休息環境，雀客藏居台北南港不僅有完善的住宿需求供應，更強調美感與品味兼具。\r\n\r\nSleeping 睡眠品質很重要：\r\n與國際星級香格里拉 Shangri-La、萬豪酒店Marriot同步選用SIMMONS，讓您能擁有國際5星級旅館的享受。\r\n\r\nEco-friendly 把環保放在心上：\r\n房內吊燈與檯燈選用在歐美熱賣的MIT台灣品牌Mr. Wattson，柔和的LED光源省電又環保，主體取自使用期限長的梣木、易於回收重熔使用的鋁合金燈罩，有效且充分利用資源，為地球盡一份心力。\r\n\r\nDesigning 設計感隨處可見：\r\n從室內裝潢到備品設計我們都很在意，淺木紋創造溫潤質感，白與深藍的搭配帶來平靜與舒適的感受，在選材、選品上的堅持，讓您打開房門之後 Wow 聲連連、驚喜不斷。',
#   'cancel_policies': [{'start_days': None,
#     'end_days': 3,
#     'percent': 100,
#     'description': '不收取任何費用'},
#    {'start_days': 2, 'end_days': 1, 'percent': 50, 'description': '收取50%已付金額'},
#    {'start_days': 0,
#     'end_days': 0,
#     'percent': 0,
#     'description': '收取100%已付金額'}],
#   'notice': '【一般旅館適用】\r\n►館內附設地下停車場，限高190公分，數量有限無法預約；如需相關資訊，請洽櫃台服務專線。\r\n\r\n1.館內全館禁菸，無提供寵物住宿，如有發現吸菸或攜帶寵物入住，將加收3000元清潔費，如有設備損壞乃需照價賠償。\r\n2.住宿房型依房間格局不同會有變化，照片僅供參考。\r\n3.貴重物品請隨身保管，或放置房內個人保險箱，若遺失本館不予負責。\r\n4.為維護住宿品質，夜間22:00後請降低音量，避免影響其他旅客權益。\r\n5.本館保留一切修改飯店注意事項之權利。\r\n►更多活動資訊請洽旅館官方網站或FB粉絲專頁。',
#   'cancel_notice': '【一般旅館適用】\r\n※第三方訂房平台或其他預訂管道，將不適用以下官網預訂取消政策。\r\n※完成預訂後，請確認是否收到訂房通知簡訊/信件，如需協助請致電訂房中心。\r\n※繳費期限為訂房後24小時，未於時效內使用點數或刷卡支付訂單30%款項，系統將自動取消訂單並釋出訂房，請貴賓重新操作訂房。\r\n※若會員點數未達訂金額度，請點選支付訂單全額；或點選支付訂金作業，完成刷卡後來電客服做點數折抵。\r\n※官網房價包含稅金及服務費，發票如有統編開立需求請於入住時提出，發票開立7日內僅提供一次更改，並請妥善留存紙本發票。\r\n\r\n依照觀光局訂房定型化契約規定，訂單成立後旅店將收取約定房費作為訂房擔保，旅客解除契約時，應通知業者，並得要求業者依下列基準處理：\r\n預先支付訂金者，將收取總房費30%，餘款將於入住首日支付。\r\n預訂取消規則如下：\r\n1. 旅客於約定住宿前3日通知取消者，可退款100%已付金額。\r\n2. 旅客於約定住宿前1-2日通知取消者，扣款已付金額50%後可申請退費。\r\n3. 旅客約定住宿當日通知取消或未如期入住者(no show)，應負擔100%已付金額為取消費用。\r\n4. 約定住宿抵達3日內，如需修改訂單內容，將依照取消規定比例收取費用。\r\n住房當日若遇氣象局發佈陸上颱風警報(旅客之出發地、抵達地、或是旅途必經途中任何一區位於公告之警戒區域)，於警報解除前可提供全數退款，亦可全額保留於申請日後一年內住房折抵使用。\r\n※款項保留者，如逾期未使用或訂房後未入住(no show)，將沒收保留全額款項不另行通知。\r\n※匯款退費之手續費由收款人負擔，不另提供出款證明，如需協助請洽客服中心。\r\n※退款作業需7-14天工作日，如遇例假日或國定假日將順延作業流程，還請貴賓耐心等候。\r\n\r\nHotel cancellation policy\r\n※ Third-party booking platforms (Online Travel Agent) does not apply to the cancellation policy on the official website.\r\n※ After completing the reservation, please confirm whether you have received the reservation notification SMS/letter. If you need assistance, please call the reservation center.\r\n※ Please pay the outstanding payment in 24hrs or your reservation will be cancelled automatically. If so, please reserve it again.\r\n※ The price on the official website includes taxes and service fees. \r\n\r\nIf there is a demand for tax ID of invoices, please put forward at the time of check-in. Only one change is provided within 7 days after the invoice is issued, and please properly keep the invoice.\r\n\r\nThose who pay the deposit in advance will be charged 30% of the total room charge, and the balance will be paid on the first day of stay.\r\nWhen the passenger rescinds the contract, he/she shall notify the operator, and may require the operator to handle according as below:\r\n1. Customers who notify the cancellation 3 days before the check-in date are entitled to a 100% refund of the room charge.\r\n2. Customers who notify cancellation 1-2 days before the check-in date can apply for refund after deducting 50% of the room charge.\r\n3. Customers who notify the cancellation or no show on the same day, the room charge is non-refundable.\r\n4. If you need to modify the order content within 3 days after the arrival date, you will be charged according to the cancellation ratio.\r\n\r\nIf an onshore typhoon warning is issued by the weather bureau on the check-in date, the full amount can be refunded before the warning is lifted, and the full amount can also be retained for next booking within one year of the application date.\r\n\r\n※ If the person who retains the money fails to use the room within the time limit or does not show the room after the reservation, the full amount of the money will be confiscated without further notice.\r\n※ The service charge for remittance refund shall be borne by the payee, and no proof of payment will be provided. If you need assistance, please contact the customer service center.\r\n※ Refund operation takes 7-14 working days. In case of a holiday or a national holiday, the operation process will be postponed. Please wait patiently.',
#   'booking_notice': '【一般旅館適用】\r\n►入住時間為15:00後；退房時間：中午11:00以前。\r\n►辦理入住時，請備妥入住人身分證件以便進行登記。\r\n館內採自助機台入住報到，欲使用觀光局自由行紙本票卷或第三方實體住宿卷折抵，請洽櫃台人員協助，如有任何需求亦可使用自助機台旁黑色電話聯繫客服為您服務。\r\n\r\n1.如有提早入住或延後退房需求將酌收額外費用，請於預訂時告知客服或櫃台人員辦理登記，相關費用將依平假日/連續假期等浮動調整。\r\n2.館內全館禁菸，無提供寵物住宿，如有發現吸菸或攜帶寵物入住，將加收3000元清潔費，如有設備損壞乃需照價賠償。\r\n3.相關訂房住宿規範，依本館公告為主，如有疑問請於【訂房/繳費】前來電洽詢。\r\n4.相關退訂政策請參閱【取消訂房須知】。\r\n5.官網房型售價不包含加人、加床費用，如需協助請另洽訂房中心。\r\n6.館內提供雙人及四人房型，超過房型指定人數且6歲(含)以上，將加收加人(含備品)費用，請洽訂房中心安排。\r\n►加人900元/人(含備品)\r\n►每房提供1位0-5歲孩童免費同住，如超過前述入住人數，將收取1位加人費用。\r\n連續及特殊假期日將依照政府行政機關辦公日曆表公告\r\n7.官網訂房售價已含服務費及營業稅，本館保留一切修改訂房須知之權利。\r\n8.預訂完成後，請於24小時內完成款項支付，第三方訂房平台之訂單請參照平台訂房規定。',
#   'country': {'name': '臺灣'},
#   'province': {'name': '台灣省'},
#   'county': {'name': '臺北市'},
#   'district': {'name': '南港區'},
#   'facilities': [{'id': 1, 'name': '24小時接待入住', 'is_popular': True},
#    {'id': 3, 'name': '24小時櫃檯服務', 'is_popular': False},
#    {'id': 5, 'name': '免費停車位（數量有限）', 'is_popular': False},
#    {'id': 9, 'name': '行李寄放服務', 'is_popular': False},
#    {'id': 10, 'name': 'master刷卡服務', 'is_popular': False},
#    {'id': 11, 'name': 'visa刷卡服務', 'is_popular': False},
#    {'id': 12, 'name': '專人辦理入住/退房', 'is_popular': False},
#    {'id': 13, 'name': '電梯', 'is_popular': False},
#    {'id': 16, 'name': '所有房型免費 Wi-Fi', 'is_popular': False},
#    {'id': 26, 'name': '中文', 'is_popular': False},
#    {'id': 27, 'name': '英文', 'is_popular': False},
#    {'id': 36, 'name': '禁菸飯店', 'is_popular': True},
#    {'id': 66, 'name': '可代收包裹', 'is_popular': True},
#    {'id': 69, 'name': '可代收外送', 'is_popular': True},
#    {'id': 89, 'name': '急救箱', 'is_popular': False},
#    {'id': 90, 'name': '滅火器', 'is_popular': False},
#    {'id': 94, 'name': 'CCTV監視器', 'is_popular': False},
#    {'id': 95, 'name': 'AED心臟去顫器', 'is_popular': False},
#    {'id': 39, 'name': '付費機場接送', 'is_popular': False},
#    {'id': 73, 'name': '電子支付服務', 'is_popular': False},
#    {'id': 84, 'name': '每日清潔消毒', 'is_popular': False},
#    {'id': 85, 'name': '每日房外收取垃圾', 'is_popular': False},
#    {'id': 86, 'name': '房客入住前客房消毒', 'is_popular': False},
#    {'id': 87, 'name': '房客及員工體溫測量', 'is_popular': False},
#    {'id': 88, 'name': '員工佩戴口罩與面罩', 'is_popular': False},
#    {'id': 92, 'name': '煙霧偵測器', 'is_popular': False}],
#   'images': [{'title': 'title1',
#     'intro': 'intro1',
#     'url': 'http://image.pms.tw/image/hotel/2340DChX23PkQR04xsPIzA4.png',
#     'ranking': 1},
#    {'title': 'title2',
#     'intro': 'intro2',
#     'url': 'http://image.pms.tw/image/hotel/234xwSQ6OU2CS8mwuLQ2WY6.png',
#     'ranking': 2},
#    {'title': 'title3',
#     'intro': 'intro3',
#     'url': 'http://image.pms.tw/image/hotel/234YPuObFer1KxQ6hwlN68d.jpg',
#     'ranking': 3},
#    {'title': 'title4',
#     'intro': 'intro4',
#     'url': 'http://image.pms.tw/image/hotel/2348TshzQ58TRKzwsqXXxts.jpg',
#     'ranking': 4},
#    {'title': 'title5',
#     'intro': 'intro5',
#     'url': 'http://image.pms.tw/image/hotel/234qDj4XyfIKYzqdaCvYxE1.jpg',
#     'ranking': 5},
#    {'title': 'title6',
#     'intro': 'intro6',
#     'url': 'http://image.pms.tw/image/hotel/234b9jU5ILhggCRHcfxkh7a.jpg',
#     'ranking': 6}]},
#  {'id': 44,
#   'status': 'OPEN',
#   'domain': 'checkinnselecttaipeiyangmingshan',
#   'name': '雀客藏居台北陽明山',
#   'phone': '0228 616 661',
#   'meals': [1],
#   'url': 'https://www.mastripms.com/checkinnselecttaipeiyangmingshan/view',
#   'check_in': '15:00:00',
#   'last_check_in': '15:00:00',
#   'check_out': '11:00:00',
#   'service_mail': 'reservation.service@dunqian.com',
#   'child_age': 12,
#   'address': '111台北市士林區格致路237號No. 237, Gezhi Rd., Shilin Dist., Taipei City 111, Taiwan (R.O.C.)',
#   'latitude': 22.6293,
#   'longitude': 120.29073,
#   'intro': '【群山環繞的隱世飯店:雀客藏居 台北陽明山溫泉飯店】\r\n藏於陽明山中的隱世飯店。追求隱山水而居,傳承千年院居哲學。飯店地理位置的優勢,距離台北市區只要30分鐘車程,就能立即擁有這份與世隔絕的靜謐。亦可選擇公車輕鬆抵達,隨時都能來一場泡湯之旅!飯店距離陽明山國家公園僅15分鐘車程,每逢花季伴隨滿山櫻花,更是一房難求,是陽明山渡假的首選。\r\n房間設計採日式風格，提供種類多樣的溫泉客房，可享受房內泡湯的樂趣，保有隱私又能徹底放鬆，窗外更一覽紗帽山景色，沉浸在群山環繞、綠意盎然的自然美景中。\r\n公共區域設有優質的白磺溫泉，在花季時刻能一邊泡湯一邊賞櫻，美不勝收！另有山泉泳池及親子戲水池，夏日酷暑最適合帶小朋友一同上山降溫遊玩。\r\n餐飲方面，結合陽明山上的特色食材，設計一系列中式的餐點，並特聘香港主廚長期駐店提供優質的餐飲服務。另配有專業會議設施的會議廳，可搭配住房專案全面式服務，創造高效舒適的會議空間。',
#   'cancel_policies': [{'start_days': None,
#     'end_days': 3,
#     'percent': 100,
#     'description': '不收取任何費用'},
#    {'start_days': 2, 'end_days': 1, 'percent': 50, 'description': '收取50%已付金額'},
#    {'start_days': 0,
#     'end_days': 0,
#     'percent': 0,
#     'description': '收取100%已付金額'}],
#   'notice': '【一般旅館適用】\r\n►館內附設平面停車場，數量有限無法預約；如需相關資訊，請洽櫃台服務專線。\r\n\r\n1.館內全館禁菸，無提供寵物住宿，如有發現吸菸或攜帶寵物入住，將加收3000元清潔費，如有設備損壞乃需照價賠償。\r\n2.住宿房型依房間格局不同會有變化，照片僅供參考。\r\n3.貴重物品請隨身保管，或放置房內個人保險箱，若遺失本館不予負責。\r\n4.為維護住宿品質，夜間22:00後請降低音量，避免影響其他旅客權益。\r\n5.本館保留一切修改飯店注意事項之權利。\r\n►更多活動資訊請洽旅館官方網站或FB粉絲專頁。',
#   'cancel_notice': '【一般旅館適用】\r\n※第三方訂房平台或其他預訂管道，將不適用以下官網預訂取消政策。\r\n※完成預訂後，請確認是否收到訂房通知簡訊/信件，如需協助請致電訂房中心。\r\n※繳費期限為訂房後24小時，未於時效內使用點數或刷卡支付訂單30%款項，系統將自動取消訂單並釋出訂房，請貴賓重新操作訂房。\r\n※若會員點數未達訂金額度，請點選支付訂單全額；或點選支付訂金作業，完成刷卡後來電客服做點數折抵。\r\n※官網房價包含稅金及服務費，發票如有統編開立需求請於入住時提出，發票開立7日內僅提供一次更改，並請妥善留存紙本發票。\r\n\r\n依照觀光局訂房定型化契約規定，訂單成立後旅店將收取約定房費作為訂房擔保，旅客解除契約時，應通知業者，並得要求業者依下列基準處理：\r\n預先支付訂金者，將收取總房費30%，餘款將於入住首日支付。\r\n預訂取消規則如下：\r\n1. 旅客於約定住宿前3日通知取消者，可退款100%已付金額。\r\n2. 旅客於約定住宿前1-2日通知取消者，扣款已付金額50%後可申請退費。\r\n3. 旅客約定住宿當日通知取消或未如期入住者(no show)，應負擔100%已付金額為取消費用。\r\n4. 約定住宿抵達3日內，如需修改訂單內容，將依照取消規定比例收取費用。\r\n住房當日若遇氣象局發佈陸上颱風警報(旅客之出發地、抵達地、或是旅途必經途中任何一區位於公告之警戒區域)，於警報解除前可提供全數退款，亦可全額保留於申請日後一年內住房折抵使用。\r\n※款項保留者，如逾期未使用或訂房後未入住(no show)，將沒收保留全額款項不另行通知。\r\n※匯款退費之手續費由收款人負擔，不另提供出款證明，如需協助請洽客服中心。\r\n※退款作業需7-14天工作日，如遇例假日或國定假日將順延作業流程，還請貴賓耐心等候。\r\n\r\nHotel cancellation policy\r\n※ Third-party booking platforms (Online Travel Agent) does not apply to the cancellation policy on the official website.\r\n※ After completing the reservation, please confirm whether you have received the reservation notification SMS/letter. If you need assistance, please call the reservation center.\r\n※ Please pay the outstanding payment in 24hrs or your reservation will be cancelled automatically. If so, please reserve it again.\r\n※ The price on the official website includes taxes and service fees. \r\n\r\nIf there is a demand for tax ID of invoices, please put forward at the time of check-in. Only one change is provided within 7 days after the invoice is issued, and please properly keep the invoice.\r\n\r\nThose who pay the deposit in advance will be charged 30% of the total room charge, and the balance will be paid on the first day of stay.\r\nWhen the passenger rescinds the contract, he/she shall notify the operator, and may require the operator to handle according as below:\r\n1. Customers who notify the cancellation 3 days before the check-in date are entitled to a 100% refund of the room charge.\r\n2. Customers who notify cancellation 1-2 days before the check-in date can apply for refund after deducting 50% of the room charge.\r\n3. Customers who notify the cancellation or no show on the same day, the room charge is non-refundable.\r\n4. If you need to modify the order content within 3 days after the arrival date, you will be charged according to the cancellation ratio.\r\n\r\nIf an onshore typhoon warning is issued by the weather bureau on the check-in date, the full amount can be refunded before the warning is lifted, and the full amount can also be retained for next booking within one year of the application date.\r\n\r\n※ If the person who retains the money fails to use the room within the time limit or does not show the room after the reservation, the full amount of the money will be confiscated without further notice.\r\n※ The service charge for remittance refund shall be borne by the payee, and no proof of payment will be provided. If you need assistance, please contact the customer service center.\r\n※ Refund operation takes 7-14 working days. In case of a holiday or a national holiday, the operation process will be postponed. Please wait patiently.',
#   'booking_notice': '【一般旅館適用】\r\n►入住時間為15:00後；退房時間：中午11:00以前。\r\n►辦理入住時，請備妥入住人身分證件以便進行登記。\r\n\r\n1.如有提早入住或延後退房需求將酌收額外費用，請於預訂時告知客服或櫃台人員辦理登記，相關費用將依平假日/連續假期等浮動調整。\r\n2.館內全館禁菸，無提供寵物住宿，如有發現吸菸或攜帶寵物入住，將加收3000元清潔費，如有設備損壞乃需照價賠償。\r\n3.相關訂房住宿規範，依本館公告為主，如有疑問請於【訂房/繳費】前來電洽詢。\r\n4.相關退訂政策請參閱【取消訂房須知】。\r\n5.官網房型售價不包含加人、加床費用，如需協助請另洽訂房中心。\r\n6.館內提供雙人及四人房型，超過房型指定人數且6歲(含)以上，將加收加人或加床費用，請洽訂房中心安排。\r\n►加床1200元/人(含床組及備品，數量有限並採預約制)\r\n►加人1200元/人(含備品)\r\n►每房提供1位0-5歲孩童免費同住，如超過前述入住人數，將收取1位加人費用。\r\n連續及特殊假期日將依照政府行政機關辦公日曆表公告\r\n7.官網訂房售價已含服務費及營業稅，本館保留一切修改訂房須知之權利。\r\n8.預訂完成後，請於24小時內完成款項支付，第三方訂房平台之訂單請參照平台訂房規定。',
#   'country': {'name': '臺灣'},
#   'province': {'name': '台灣省'},
#   'county': {'name': '臺北市'},
#   'district': {'name': '士林區'},
#   'facilities': [{'id': 10, 'name': 'master刷卡服務', 'is_popular': False},
#    {'id': 11, 'name': 'visa刷卡服務', 'is_popular': False},
#    {'id': 14, 'name': '公共區域免費上網', 'is_popular': False},
#    {'id': 16, 'name': '所有房型免費 Wi-Fi', 'is_popular': False},
#    {'id': 26, 'name': '中文', 'is_popular': False},
#    {'id': 27, 'name': '英文', 'is_popular': False},
#    {'id': 36, 'name': '禁菸飯店', 'is_popular': True},
#    {'id': 1, 'name': '24小時接待入住', 'is_popular': True},
#    {'id': 3, 'name': '24小時櫃檯服務', 'is_popular': False},
#    {'id': 5, 'name': '免費停車位（數量有限）', 'is_popular': False},
#    {'id': 8, 'name': '無障礙設施', 'is_popular': False},
#    {'id': 9, 'name': '行李寄放服務', 'is_popular': False},
#    {'id': 18, 'name': '健身房', 'is_popular': False},
#    {'id': 20, 'name': '餐廳', 'is_popular': False},
#    {'id': 22, 'name': '溫泉', 'is_popular': False},
#    {'id': 30, 'name': '客房餐飲服務', 'is_popular': False},
#    {'id': 39, 'name': '付費機場接送', 'is_popular': False},
#    {'id': 43, 'name': '戶外游泳池', 'is_popular': False},
#    {'id': 46, 'name': '電動遊戲室', 'is_popular': False},
#    {'id': 48, 'name': '咖啡廳', 'is_popular': False},
#    {'id': 51, 'name': '會議室', 'is_popular': False},
#    {'id': 56, 'name': '代客叫車服務', 'is_popular': False},
#    {'id': 63, 'name': '宴會廳', 'is_popular': False},
#    {'id': 64, 'name': '婚宴服務', 'is_popular': False},
#    {'id': 73, 'name': '電子支付服務', 'is_popular': False},
#    {'id': 75, 'name': '娛樂設備租借', 'is_popular': True},
#    {'id': 80, 'name': '公共飲水機', 'is_popular': False},
#    {'id': 83, 'name': '電動車充電站', 'is_popular': False},
#    {'id': 84, 'name': '每日清潔消毒', 'is_popular': False},
#    {'id': 87, 'name': '房客及員工體溫測量', 'is_popular': False},
#    {'id': 88, 'name': '員工佩戴口罩與面罩', 'is_popular': False},
#    {'id': 89, 'name': '急救箱', 'is_popular': False},
#    {'id': 90, 'name': '滅火器', 'is_popular': False},
#    {'id': 92, 'name': '煙霧偵測器', 'is_popular': False},
#    {'id': 94, 'name': 'CCTV監視器', 'is_popular': False},
#    {'id': 95, 'name': 'AED心臟去顫器', 'is_popular': False}],
#   'images': [{'title': 'title1',
#     'intro': 'intro1',
#     'url': 'http://image.pms.tw/image/hotel/612afGosuxdoDUr2eeVYSFe.jpg',
#     'ranking': 1},
#    {'title': 'title2',
#     'intro': 'intro2',
#     'url': 'http://image.pms.tw/image/hotel/612U3ztbeoRm0KltpX7j3X2.png',
#     'ranking': 2},
#    {'title': 'title3',
#     'intro': 'intro3',
#     'url': 'http://image.pms.tw/image/hotel/6128ECQ509KHu7xqA2FqtCn.png',
#     'ranking': 3},
#    {'title': 'title4',
#     'intro': 'intro4',
#     'url': 'http://image.pms.tw/image/hotel/612Ph3umfp28bY4Y7Id65hQ.jpg',
#     'ranking': 4},
#    {'title': 'title5',
#     'intro': 'intro5',
#     'url': 'http://image.pms.tw/image/hotel/612HDQeTK5YP4o8edHhEnFu.jpg',
#     'ranking': 5},
#    {'title': 'title6',
#     'intro': 'intro6',
#     'url': 'http://image.pms.tw/image/hotel/612hVbk8Z3TLdasWFpe44Va.jpg',
#     'ranking': 6},
#    {'title': 'title7',
#     'intro': 'intro7',
#     'url': 'http://image.pms.tw/image/hotel/612HGzODkjGabFp6YRSO13k.jpg',
#     'ranking': 7},
#    {'title': 'title8',
#     'intro': 'intro8',
#     'url': 'http://image.pms.tw/image/hotel/612YTO8zzXrrzJ006TPROMd.png',
#     'ranking': 8},
#    {'title': 'title9',
#     'intro': 'intro9',
#     'url': 'http://image.pms.tw/image/hotel/612PMGNyRFyL4Wx5I8DUx6b.png',
#     'ranking': 9},
#    {'title': 'title10',
#     'intro': 'intro10',
#     'url': 'http://image.pms.tw/image/hotel/6124H5thrczjd9QkV2arqY9.png',
#     'ranking': 10},
#    {'title': 'title11',
#     'intro': 'intro11',
#     'url': 'http://image.pms.tw/image/hotel/612Esfqhut5brY06Gn0Xdj1.png',
#     'ranking': 11},
#    {'title': 'title12',
#     'intro': 'intro12',
#     'url': 'http://image.pms.tw/image/hotel/612HujNsFd8BsMveWsQP4pW.png',
#     'ranking': 12},
#    {'title': 'title13',
#     'intro': 'intro13',
#     'url': 'http://image.pms.tw/image/hotel/612ZEEosHbCv1JuTwrWWu6z.jpg',
#     'ranking': 13},
#    {'title': 'title14',
#     'intro': 'intro14',
#     'url': 'http://image.pms.tw/image/hotel/6122OYyrTkoT2FJfM0HBRXg.jpg',
#     'ranking': 14},
#    {'title': 'title15',
#     'intro': 'intro15',
#     'url': 'http://image.pms.tw/image/hotel/612TYFfi2eSy0Ni4ywGj2vo.jpg',
#     'ranking': 15},
#    {'title': 'title16',
#     'intro': 'intro16',
#     'url': 'http://image.pms.tw/image/hotel/612YQz48CWgg864Q3ludJLz.jpg',
#     'ranking': 16}]},
#  {'id': 42,
#   'status': 'OPEN',
#   'domain': 'checkinnselectntsw',
#   'name': '雀客藏居新北三重水漾',
#   'phone': '',
#   'meals': None,
#   'url': 'https://www.mastripms.com/checkinnselectntsw/view',
#   'check_in': '15:00:00',
#   'last_check_in': '23:59:00',
#   'check_out': '11:00:00',
#   'service_mail': 'reservation.service@dunqian.com',
#   'child_age': 6,
#   'address': '241新北市三重區捷運路77號 No. 77, Jieyun Rd., Sanchong Dist., New Taipei City 241, Taiwan (R.O.C.)',
#   'latitude': None,
#   'longitude': None,
#   'intro': '位於機捷三重站，搭乘機場捷運，距離台北站僅一站之距，五分鐘即可輕鬆抵達。館內多樣風格房型可供選擇：適合出差旅遊短暫停留的高級客房，擁有廚房、洗衣機等設備一應俱全的長住型套房，都為每位旅客提供最舒適的休憩空間。\r\n全館提供免治馬桶，床墊採用Slumberland斯里百蘭名床，讓您擁有國際五星級的睡眠享受！鄰近新北大都會公園，無遮擋的開闊視野，在傍晚時分，可欣賞公園無邊際壯闊的落日餘暉。',
#   'cancel_policies': [{'start_days': None,
#     'end_days': 3,
#     'percent': 100,
#     'description': '不收取任何費用'},
#    {'start_days': 2, 'end_days': 1, 'percent': 50, 'description': '收取50%已付金額'},
#    {'start_days': 0,
#     'end_days': 0,
#     'percent': 0,
#     'description': '收取100%已付金額'}],
#   'notice': '【一般旅館適用】\r\n►館內附設地下停車場，限高210公分，數量有限無法預約；如需相關資訊，請洽櫃台服務專線。\r\n\r\n1.館內全館禁菸，無提供寵物住宿，如有發現吸菸或攜帶寵物入住，將加收3000元清潔費，如有設備損壞乃需照價賠償。\r\n2.住宿房型依房間格局不同會有變化，照片僅供參考。\r\n3.貴重物品請隨身保管，若遺失本館不予負責。\r\n4.為維護住宿品質，夜間22:00後請降低音量，避免影響其他旅客權益。\r\n5.本館保留一切修改飯店注意事項之權利。\r\n►更多活動資訊請洽旅館官方網站或FB粉絲專頁。',
#   'cancel_notice': '【一般旅館適用】\r\n※第三方訂房平台或其他預訂管道，將不適用以下官網預訂取消政策。\r\n※完成預訂後，請確認是否收到訂房通知簡訊/信件，如需協助請致電訂房中心。\r\n※繳費期限為訂房後24小時，未於時效內使用點數或刷卡支付訂單30%款項，系統將自動取消訂單並釋出訂房，請貴賓重新操作訂房。\r\n※若會員點數未達訂金額度，請點選支付訂單全額；或點選支付訂金作業，完成刷卡後來電客服做點數折抵。\r\n※官網房價包含稅金及服務費，發票如有統編開立需求請於入住時提出，發票開立7日內僅提供一次更改，並請妥善留存紙本發票。\r\n\r\n依照觀光局訂房定型化契約規定，訂單成立後旅店將收取約定房費作為訂房擔保，旅客解除契約時，應通知業者，並得要求業者依下列基準處理：\r\n預先支付訂金者，將收取總房費30%，餘款將於入住首日支付。\r\n預訂取消規則如下：\r\n1. 旅客於約定住宿前3日通知取消者，可退款100%已付金額。\r\n2. 旅客於約定住宿前1-2日通知取消者，扣款已付金額50%後可申請退費。\r\n3. 旅客約定住宿當日通知取消或未如期入住者(no show)，應負擔100%已付金額為取消費用。\r\n4. 約定住宿抵達3日內，如需修改訂單內容，將依照取消規定比例收取費用。\r\n住房當日若遇氣象局發佈陸上颱風警報(旅客之出發地、抵達地、或是旅途必經途中任何一區位於公告之警戒區域)，於警報解除前可提供全數退款，亦可全額保留於申請日後一年內住房折抵使用。\r\n※款項保留者，如逾期未使用或訂房後未入住(no show)，將沒收保留全額款項不另行通知。\r\n※匯款退費之手續費由收款人負擔，不另提供出款證明，如需協助請洽客服中心。\r\n※退款作業需7-14天工作日，如遇例假日或國定假日將順延作業流程，還請貴賓耐心等候。\r\n\r\nHotel cancellation policy\r\n※ Third-party booking platforms (Online Travel Agent) does not apply to the cancellation policy on the official website.\r\n※ After completing the reservation, please confirm whether you have received the reservation notification SMS/letter. If you need assistance, please call the reservation center.\r\n※ Please pay the outstanding payment in 24hrs or your reservation will be cancelled automatically. If so, please reserve it again.\r\n※ The price on the official website includes taxes and service fees. \r\n\r\nIf there is a demand for tax ID of invoices, please put forward at the time of check-in. Only one change is provided within 7 days after the invoice is issued, and please properly keep the invoice.\r\n\r\nThose who pay the deposit in advance will be charged 30% of the total room charge, and the balance will be paid on the first day of stay.\r\nWhen the passenger rescinds the contract, he/she shall notify the operator, and may require the operator to handle according as below:\r\n1. Customers who notify the cancellation 3 days before the check-in date are entitled to a 100% refund of the room charge.\r\n2. Customers who notify cancellation 1-2 days before the check-in date can apply for refund after deducting 50% of the room charge.\r\n3. Customers who notify the cancellation or no show on the same day, the room charge is non-refundable.\r\n4. If you need to modify the order content within 3 days after the arrival date, you will be charged according to the cancellation ratio.\r\n\r\nIf an onshore typhoon warning is issued by the weather bureau on the check-in date, the full amount can be refunded before the warning is lifted, and the full amount can also be retained for next booking within one year of the application date.\r\n\r\n※ If the person who retains the money fails to use the room within the time limit or does not show the room after the reservation, the full amount of the money will be confiscated without further notice.\r\n※ The service charge for remittance refund shall be borne by the payee, and no proof of payment will be provided. If you need assistance, please contact the customer service center.\r\n※ Refund operation takes 7-14 working days. In case of a holiday or a national holiday, the operation process will be postponed. Please wait patiently.',
#   'booking_notice': '【一般旅館適用】\r\n►入住時間為15:00後；退房時間：中午11:00以前。\r\n►辦理入住時，請備妥入住人身分證件以便進行登記。\r\n館內採自助機台入住報到，欲使用觀光局自由行紙本票卷或第三方實體住宿卷折抵，請洽櫃台人員協助，如有任何需求亦可使用自助機台旁黑色電話聯繫客服為您服務。\r\n\r\n1.如有提早入住或延後退房需求將酌收額外費用，請於預訂時告知客服或櫃台人員辦理登記，相關費用將依平假日/連續假期等浮動調整。\r\n2.館內全館禁菸，無提供寵物住宿，如有發現吸菸或攜帶寵物入住，將加收3000元清潔費，如有設備損壞乃需照價賠償。\r\n3.相關訂房住宿規範，依本館公告為主，如有疑問請於【訂房/繳費】前來電洽詢。\r\n4.相關退訂政策請參閱【取消訂房須知】。\r\n5.官網房型售價不包含加人、加床費用，如需協助請另洽訂房中心。\r\n6.館內提供雙人及四人房型，超過房型指定人數且6歲(含)以上，將加收加人(含備品)費用，請洽訂房中心安排。\r\n►加床(僅限藏居雙人套房-日式臥榻，至多兩床) 1200元/床(含備品)\r\n►加人900元/人(含備品)\r\n►每房提供1位0-5歲孩童免費同住，如超過前述入住人數，將收取1位加人費用。\r\n連續及特殊假期日將依照政府行政機關辦公日曆表公告\r\n7.官網訂房售價已含服務費及營業稅，本館保留一切修改訂房須知之權利。\r\n8.預訂完成後，請於24小時內完成款項支付，第三方訂房平台之訂單請參照平台訂房規定。',
#   'country': {'name': '臺灣'},
#   'province': {'name': '台灣省'},
#   'county': {'name': '新北市'},
#   'district': {'name': '三重區'},
#   'facilities': [{'id': 10, 'name': 'master刷卡服務', 'is_popular': False},
#    {'id': 11, 'name': 'visa刷卡服務', 'is_popular': False},
#    {'id': 13, 'name': '電梯', 'is_popular': False},
#    {'id': 16, 'name': '所有房型免費 Wi-Fi', 'is_popular': False},
#    {'id': 26, 'name': '中文', 'is_popular': False},
#    {'id': 27, 'name': '英文', 'is_popular': False},
#    {'id': 1, 'name': '24小時接待入住', 'is_popular': True},
#    {'id': 3, 'name': '24小時櫃檯服務', 'is_popular': False},
#    {'id': 5, 'name': '免費停車位（數量有限）', 'is_popular': False},
#    {'id': 9, 'name': '行李寄放服務', 'is_popular': False},
#    {'id': 39, 'name': '付費機場接送', 'is_popular': False},
#    {'id': 51, 'name': '會議室', 'is_popular': False},
#    {'id': 80, 'name': '公共飲水機', 'is_popular': False},
#    {'id': 89, 'name': '急救箱', 'is_popular': False},
#    {'id': 90, 'name': '滅火器', 'is_popular': False},
#    {'id': 92, 'name': '煙霧偵測器', 'is_popular': False},
#    {'id': 94, 'name': 'CCTV監視器', 'is_popular': False},
#    {'id': 95, 'name': 'AED心臟去顫器', 'is_popular': False}],
#   'images': [{'title': 'title1',
#     'intro': 'intro1',
#     'url': 'http://image.pms.tw/image/hotel/562UloxeQlgu5fSMycBrGrI.jpg',
#     'ranking': 1},
#    {'title': 'title2',
#     'intro': 'intro2',
#     'url': 'http://image.pms.tw/image/hotel/562yl4LANfsUjgJMnrCwwgq.png',
#     'ranking': 2},
#    {'title': 'title3',
#     'intro': 'intro3',
#     'url': 'http://image.pms.tw/image/hotel/562StQypSIo41Mm0IBizwE9.png',
#     'ranking': 3},
#    {'title': 'title4',
#     'intro': 'intro4',
#     'url': 'http://image.pms.tw/image/hotel/562mb4708Nm05yenxLyULiS.jpg',
#     'ranking': 4},
#    {'title': 'title5',
#     'intro': 'intro5',
#     'url': 'http://image.pms.tw/image/hotel/562au6XjPmFRvfPGCkFEVWE.png',
#     'ranking': 5},
#    {'title': 'title6',
#     'intro': 'intro6',
#     'url': 'http://image.pms.tw/image/hotel/562Ra040wx0Xe8VpGUIPhV6.png',
#     'ranking': 6},
#    {'title': 'title7',
#     'intro': 'intro7',
#     'url': 'http://image.pms.tw/image/hotel/5627ACsPrr9JMDnlMkhF8PU.png',
#     'ranking': 7},
#    {'title': 'title8',
#     'intro': 'intro8',
#     'url': 'http://image.pms.tw/image/hotel/562KrER5SwP2PCv2Th9Ud8k.png',
#     'ranking': 8},
#    {'title': 'title9',
#     'intro': 'intro9',
#     'url': 'http://image.pms.tw/image/hotel/562kcYo8P4PUrINqYi7tGTC.png',
#     'ranking': 9}]},
#  {'id': 39,
#   'status': 'OPEN',
#   'domain': 'guidehsinchuzhongyang',
#   'name': '承攜行旅新竹中央館',
#   'phone': '5212 323',
#   'meals': [1],
#   'url': 'https://www.mastripms.com/guidehsinchuzhongyang/view',
#   'check_in': '15:00:00',
#   'last_check_in': '23:59:00',
#   'check_out': '11:00:00',
#   'service_mail': 'reservation.service@dunqian.com',
#   'child_age': 12,
#   'address': '300新竹市東區中央路106號B2,1樓,8-15樓 No.106, Zhongyang Rd., East Dist., Hsinchu City 300, Taiwan (R.O.C.)',
#   'latitude': 24.80614,
#   'longitude': 120.96954,
#   'intro': '承攜行旅新竹中央館位於新竹市中心，鄰近美術館、博物館，是當地人文薈萃之地。\r\n作為探索當地文化的開端，我們提供舒適高品質的住宿環境，寬敞宜人的空間、乾淨簡單的設計，設有辦公桌椅，讓商務旅客也能有完善的辦公空間，美好的住宿體驗等你來感受。',
#   'cancel_policies': [{'start_days': None,
#     'end_days': 3,
#     'percent': 100,
#     'description': '不收取任何費用'},
#    {'start_days': 2, 'end_days': 1, 'percent': 50, 'description': '收取50%已付金額'},
#    {'start_days': 0,
#     'end_days': 0,
#     'percent': 0,
#     'description': '收取100%已付金額'}],
#   'notice': '►館內無提供停車服務，如需周邊停車相關資訊，請洽櫃台服務專線。\r\n\r\n1.館內全館禁菸，無提供寵物住宿，如有發現吸菸或攜帶寵物入住，將加收3000元清潔費，如有設備損壞乃需照價賠償。\r\n2.住宿房型依房間格局不同會有變化，照片僅供參考。\r\n3.貴重物品請隨身保管，或放置房內個人保險箱，若遺失本館不予負責。\r\n4.為維護住宿品質，夜間22:00後請降低音量，避免影響其他旅客權益。\r\n5.本館保留一切修改飯店注意事項之權利。\r\n►更多活動資訊請洽旅館官方網站或FB粉絲專頁。',
#   'cancel_notice': '※第三方訂房平台或其他預訂管道，將不適用以下官網預訂取消政策。\r\n※完成預訂後，請確認是否收到訂房通知簡訊/信件，如需協助請致電訂房中心。\r\n※繳費期限為訂房後24小時，未於時效內使用點數或刷卡支付訂單30%款項，系統將自動取消訂單並釋出訂房，請貴賓重新操作訂房。\r\n※若會員點數未達訂金額度，請點選支付訂單全額；或點選支付訂金作業，完成刷卡後來電客服做點數折抵。\r\n※官網房價包含稅金及服務費，發票如有統編開立需求請於入住時提出，發票開立7日內僅提供一次更改，並請妥善留存紙本發票。\r\n\r\n依照觀光局訂房定型化契約規定，訂單成立後旅店將收取約定房費作為訂房擔保，旅客解除契約時，應通知業者，並得要求業者依下列基準處理：\r\n預先支付訂金者，將收取總房費30%，餘款將於入住首日支付。\r\n預訂取消規則如下：\r\n1. 旅客於約定住宿前3日通知取消者，可退款100%已付金額。\r\n2. 旅客於約定住宿前1-2日通知取消者，扣款已付金額50%後可申請退費。\r\n3. 旅客約定住宿當日通知取消或未如期入住者(no show)，應負擔100%已付金額為取消費用。\r\n4. 約定住宿抵達3日內，如需修改訂單內容，將依照取消規定比例收取費用。\r\n住房當日若遇氣象局發佈陸上颱風警報(旅客之出發地、抵達地、或是旅途必經途中任何一區位於公告之警戒區域)，於警報解除前可提供全數退款，亦可全額保留於申請日後一年內住房折抵使用。\r\n※款項保留者，如逾期未使用或訂房後未入住(no show)，將沒收保留全額款項不另行通知。\r\n※匯款退費之手續費由收款人負擔，不另提供出款證明，如需協助請洽客服中心。\r\n※退款作業需7-14天工作日，如遇例假日或國定假日將順延作業流程，還請貴賓耐心等候。\r\n\r\nHotel cancellation policy\r\n※ Third-party booking platforms (Online Travel Agent) does not apply to the cancellation policy on the official website.\r\n※ After completing the reservation, please confirm whether you have received the reservation notification SMS/letter. If you need assistance, please call the reservation center.\r\n※ Please pay the outstanding payment in 24hrs or your reservation will be cancelled automatically. If so, please reserve it again.\r\n※ The price on the official website includes taxes and service fees. \r\n\r\nIf there is a demand for tax ID of invoices, please put forward at the time of check-in. Only one change is provided within 7 days after the invoice is issued, and please properly keep the invoice.\r\n\r\nThose who pay the deposit in advance will be charged 30% of the total room charge, and the balance will be paid on the first day of stay.\r\nWhen the passenger rescinds the contract, he/she shall notify the operator, and may require the operator to handle according as below:\r\n1. Customers who notify the cancellation 3 days before the check-in date are entitled to a 100% refund of the room charge.\r\n2. Customers who notify cancellation 1-2 days before the check-in date can apply for refund after deducting 50% of the room charge.\r\n3. Customers who notify the cancellation or no show on the same day, the room charge is non-refundable.\r\n4. If you need to modify the order content within 3 days after the arrival date, you will be charged according to the cancellation ratio.\r\n\r\nIf an onshore typhoon warning is issued by the weather bureau on the check-in date, the full amount can be refunded before the warning is lifted, and the full amount can also be retained for next booking within one year of the application date.\r\n\r\n※ If the person who retains the money fails to use the room within the time limit or does not show the room after the reservation, the full amount of the money will be confiscated without further notice.\r\n※ The service charge for remittance refund shall be borne by the payee, and no proof of payment will be provided. If you need assistance, please contact the customer service center.\r\n※ Refund operation takes 7-14 working days. In case of a holiday or a national holiday, the operation process will be postponed. Please wait patiently.',
#   'booking_notice': '【一般旅館適用】\r\n►入住時間為15:00後；退房時間：中午11:00以前。\r\n►辦理入住時，請備妥入住人身分證件以便進行登記。\r\n館內採自助機台入住報到，欲使用觀光局自由行紙本票卷或第三方實體住宿卷折抵，請洽櫃台人員協助，如有任何需求亦可使用自助機台旁黑色電話聯繫客服為您服務。\r\n\r\n1.如有提早入住或延後退房需求將酌收額外費用，請於預訂時告知客服或櫃台人員辦理登記，相關費用將依平假日/連續假期等浮動調整。\r\n2.館內全館禁菸，無提供寵物住宿，如有發現吸菸或攜帶寵物入住，將加收3000元清潔費，如有設備損壞乃需照價賠償。\r\n3.相關訂房住宿規範，依本館公告為主，如有疑問請於【訂房/繳費】前來電洽詢。\r\n4.相關退訂政策請參閱【取消訂房須知】。\r\n5.官網房型售價不包含加人、加床費用，如需協助請另洽訂房中心。\r\n6.館內提供雙人及四人房型，超過房型指定人數且6歲(含)以上，將加收加人或加床費用，請洽訂房中心安排。\r\n►加床900元/人(含床組及備品，數量有限並採預約制)\r\n►加人700元/人(含備品)\r\n連續及特殊假期日將依照政府行政機關辦公日曆表公告\r\n7.官網訂房售價已含服務費及營業稅，本館保留一切修改訂房須知之權利。\r\n8.預訂完成後，請於24小時內完成款項支付，第三方訂房平台之訂單請參照平台訂房規定。',
#   'country': {'name': '臺灣'},
#   'province': {'name': '台灣省'},
#   'county': {'name': '新竹市'},
#   'district': {'name': '東區'},
#   'facilities': [{'id': 7, 'name': '付費停車位', 'is_popular': False},
#    {'id': 10, 'name': 'master刷卡服務', 'is_popular': False},
#    {'id': 11, 'name': 'visa刷卡服務', 'is_popular': False},
#    {'id': 13, 'name': '電梯', 'is_popular': False},
#    {'id': 14, 'name': '公共區域免費上網', 'is_popular': False},
#    {'id': 16, 'name': '所有房型免費 Wi-Fi', 'is_popular': False},
#    {'id': 26, 'name': '中文', 'is_popular': False},
#    {'id': 27, 'name': '英文', 'is_popular': False},
#    {'id': 1, 'name': '24小時接待入住', 'is_popular': True},
#    {'id': 3, 'name': '24小時櫃檯服務', 'is_popular': False},
#    {'id': 12, 'name': '專人辦理入住/退房', 'is_popular': False},
#    {'id': 28, 'name': '日文', 'is_popular': False},
#    {'id': 39, 'name': '付費機場接送', 'is_popular': False},
#    {'id': 51, 'name': '會議室', 'is_popular': False},
#    {'id': 56, 'name': '代客叫車服務', 'is_popular': False},
#    {'id': 80, 'name': '公共飲水機', 'is_popular': False},
#    {'id': 82, 'name': None, 'is_popular': False},
#    {'id': 86, 'name': '房客入住前客房消毒', 'is_popular': False},
#    {'id': 89, 'name': '急救箱', 'is_popular': False},
#    {'id': 90, 'name': '滅火器', 'is_popular': False},
#    {'id': 92, 'name': '煙霧偵測器', 'is_popular': False},
#    {'id': 94, 'name': 'CCTV監視器', 'is_popular': False}],
#   'images': [{'title': 'title1',
#     'intro': 'intro1',
#     'url': 'http://image.pms.tw/image/hotel/494rK57WubxmV0TFS6JVitO.jpg',
#     'ranking': 1},
#    {'title': 'title2',
#     'intro': 'intro2',
#     'url': 'http://image.pms.tw/image/hotel/494seXS816fJQNSCZpR0TyA.jpg',
#     'ranking': 2},
#    {'title': 'title3',
#     'intro': 'intro3',
#     'url': 'http://image.pms.tw/image/hotel/4940uBP4ffF2Zr6z6iZqoHm.jpg',
#     'ranking': 3},
#    {'title': 'title4',
#     'intro': 'intro4',
#     'url': 'http://image.pms.tw/image/hotel/494UZWklVcZPexWXxZ8UvZD.jpg',
#     'ranking': 4},
#    {'title': 'title5',
#     'intro': 'intro5',
#     'url': 'http://image.pms.tw/image/hotel/49437wYQCdvbyr1oZI3eG86.jpg',
#     'ranking': 5},
#    {'title': 'title6',
#     'intro': 'intro6',
#     'url': 'http://image.pms.tw/image/hotel/494DrLyVSFLyBEL2vwRHlkf.jpg',
#     'ranking': 6},
#    {'title': 'title7',
#     'intro': 'intro7',
#     'url': 'http://image.pms.tw/image/hotel/4942pSTJ4pYbVA3rbNu5Y1f.jpg',
#     'ranking': 7},
#    {'title': 'title8',
#     'intro': 'intro8',
#     'url': 'http://image.pms.tw/image/hotel/494RJmNDvPub0uy5LJpY37z.jpg',
#     'ranking': 8},
#    {'title': 'title9',
#     'intro': 'intro9',
#     'url': 'http://image.pms.tw/image/hotel/494TngK0Dn9SFHzAbilSoO5.jpg',
#     'ranking': 9},
#    {'title': 'title10',
#     'intro': 'intro10',
#     'url': 'http://image.pms.tw/image/hotel/494uvnMPnIHY2Recb3gcfHm.jpg',
#     'ranking': 10}]},
#  {'id': 5,
#   'status': 'OPEN',
#   'domain': 'elpuertohotel',
#   'name': '墾丁泊途會館',
#   'phone': '2319 30',
#   'meals': None,
#   'url': 'https://www.mastripms.com/elpuertohotel/view',
#   'check_in': '16:00:00',
#   'last_check_in': '22:00:00',
#   'check_out': '11:00:00',
#   'service_mail': 'reservation.service@dunqian.com',
#   'child_age': 6,
#   'address': '946屏東縣恆春鎮砂島路252號 No. 252, Shadao Rd., Hengchun Township, Pingtung County 946, Taiwan (R.O.C.)',
#   'latitude': 21.9138,
#   'longitude': 120.84786,
#   'intro': 'EL PUERTO墾丁泊途會館位於屏東縣恆春鎮，距離鵝鑾鼻燈塔只要5分鐘車程，對面是知名砂島生態保護區及貝殼砂展示館，交通便捷，周圍寧靜。\r\n大面落地窗一覽無敵海景，躺在床上看著海發呆，或是到陽台上，吹吹風曬太陽，享受南灣的獨特風情，都是絕佳的享受。\r\n寬闊的客廳區，不管是大人小孩都可以在裡面追趕跑跳，不受空間的拘束，提供最自由的住宿體驗！',
#   'cancel_policies': [{'start_days': None,
#     'end_days': 3,
#     'percent': 100,
#     'description': '不收取任何費用'},
#    {'start_days': 2, 'end_days': 1, 'percent': 50, 'description': '收取50%已付金額'},
#    {'start_days': 0,
#     'end_days': 0,
#     'percent': 0,
#     'description': '收取100%已付金額'}],
#   'notice': '【一般旅館適用】\r\n►館內無提供停車服務，如需周邊停車相關資訊，請洽櫃台服務專線。\r\n\r\n1.館內全館禁菸，無提供寵物住宿，如有發現吸菸或攜帶寵物入住，將加收3000元清潔費，如有設備損壞乃需照價賠償。\r\n2.住宿房型依房間格局不同會有變化，照片僅供參考。\r\n3.貴重物品請隨身保管，或放置房內個人保險箱，若遺失本館不予負責。\r\n4.為維護住宿品質，夜間22:00後請降低音量，避免影響其他旅客權益。\r\n5.本館保留一切修改飯店注意事項之權利。\r\n►更多活動資訊請洽旅館官方網站或FB粉絲專頁。',
#   'cancel_notice': '【一般旅館適用】\r\n※第三方訂房平台或其他預訂管道，將不適用以下官網預訂取消政策。\r\n※完成預訂後，請確認是否收到訂房通知簡訊/信件，如需協助請致電訂房中心。\r\n※繳費期限為訂房後24小時，未於時效內使用點數或刷卡支付訂單30%款項，系統將自動取消訂單並釋出訂房，請貴賓重新操作訂房。\r\n※若會員點數未達訂金額度，請點選支付訂單全額；或點選支付訂金作業，完成刷卡後來電客服做點數折抵。\r\n※官網房價包含稅金及服務費，發票如有統編開立需求請於入住時提出，發票開立7日內僅提供一次更改，並請妥善留存紙本發票。\r\n\r\n依照觀光局訂房定型化契約規定，訂單成立後旅店將收取約定房費作為訂房擔保，旅客解除契約時，應通知業者，並得要求業者依下列基準處理：\r\n預先支付訂金者，將收取總房費30%，餘款將於入住首日支付。\r\n預訂取消規則如下：\r\n1. 旅客於約定住宿前3日通知取消者，可退款100%已付金額。\r\n2. 旅客於約定住宿前1-2日通知取消者，扣款已付金額50%後可申請退費。\r\n3. 旅客約定住宿當日通知取消或未如期入住者(no show)，應負擔100%已付金額為取消費用。\r\n4. 約定住宿抵達3日內，如需修改訂單內容，將依照取消規定比例收取費用。\r\n住房當日若遇氣象局發佈陸上颱風警報(旅客之出發地、抵達地、或是旅途必經途中任何一區位於公告之警戒區域)，於警報解除前可提供全數退款，亦可全額保留於申請日後一年內住房折抵使用。\r\n※款項保留者，如逾期未使用或訂房後未入住(no show)，將沒收保留全額款項不另行通知。\r\n※匯款退費之手續費由收款人負擔，不另提供出款證明，如需協助請洽客服中心。\r\n※退款作業需7-14天工作日，如遇例假日或國定假日將順延作業流程，還請貴賓耐心等候。\r\n\r\nHotel cancellation policy\r\n※ Third-party booking platforms (Online Travel Agent) does not apply to the cancellation policy on the official website.\r\n※ After completing the reservation, please confirm whether you have received the reservation notification SMS/letter. If you need assistance, please call the reservation center.\r\n※ Please pay the outstanding payment in 24hrs or your reservation will be cancelled automatically. If so, please reserve it again.\r\n※ The price on the official website includes taxes and service fees. \r\n\r\nIf there is a demand for tax ID of invoices, please put forward at the time of check-in. Only one change is provided within 7 days after the invoice is issued, and please properly keep the invoice.\r\n\r\nThose who pay the deposit in advance will be charged 30% of the total room charge, and the balance will be paid on the first day of stay.\r\nWhen the passenger rescinds the contract, he/she shall notify the operator, and may require the operator to handle according as below:\r\n1. Customers who notify the cancellation 3 days before the check-in date are entitled to a 100% refund of the room charge.\r\n2. Customers who notify cancellation 1-2 days before the check-in date can apply for refund after deducting 50% of the room charge.\r\n3. Customers who notify the cancellation or no show on the same day, the room charge is non-refundable.\r\n4. If you need to modify the order content within 3 days after the arrival date, you will be charged according to the cancellation ratio.\r\n\r\nIf an onshore typhoon warning is issued by the weather bureau on the check-in date, the full amount can be refunded before the warning is lifted, and the full amount can also be retained for next booking within one year of the application date.\r\n\r\n※ If the person who retains the money fails to use the room within the time limit or does not show the room after the reservation, the full amount of the money will be confiscated without further notice.\r\n※ The service charge for remittance refund shall be borne by the payee, and no proof of payment will be provided. If you need assistance, please contact the customer service center.\r\n※ Refund operation takes 7-14 working days. In case of a holiday or a national holiday, the operation process will be postponed. Please wait patiently.',
#   'booking_notice': '【一般旅館適用】\r\n►入住時間為16:00後；退房時間：中午11:00以前。\r\n*如欲使用觀光局自由行紙本票卷或第三方實體住宿卷折抵，請於晚間21:30前辦理入住，避免入住時無櫃台人員協助，如有任何需求亦可撥打電話聯繫客服為您服務*\r\n\r\n1.如有提早入住或延後退房需求將酌收額外費用，請於預訂時告知客服或櫃台人員辦理登記，相關費用將依平假日/連續假期等浮動調整。\r\n2.館內全館禁菸，無提供寵物住宿，如有發現吸菸或攜帶寵物入住，將加收3000元清潔費，如有設備損壞乃需照價賠償。\r\n3.相關訂房住宿規範，依本館公告為主，如有疑問請於【訂房/繳費】前來電洽詢。\r\n4.相關退訂政策請參閱【取消訂房須知】。\r\n5.官網房型售價不包含加人、加床費用，如需協助請另洽訂房中心。\r\n6.館內提供雙人及四人房型，超過房型指定人數且6歲(含)以上，將加收加人或加床費用，請洽訂房中心安排。\r\n►旺季 (暑假 07/01-08/31)\r\n加人900元/人、加床1100元/人；不分平假日或連續假日\r\n►淡季 (非暑假 01/01-06/30及09/01-12/31)\r\n加人700元/人、加床900元/人；不分平假日或連續假日\r\n►每房提供1位0-5歲孩童免費同住，如超過前述入住人數，將收取1位加人費用。\r\n連續及特殊假期日將依照政府行政機關辦公日曆表公告\r\n7.官網訂房售價已含服務費及營業稅，本館保留一切修改訂房須知之權利。\r\n8.預訂完成後，請於24小時內完成款項支付，第三方訂房平台之訂單請參照平台訂房規定。',
#   'country': {'name': '臺灣'},
#   'province': {'name': '台灣省'},
#   'county': {'name': '屏東縣'},
#   'district': {'name': '恆春鎮'},
#   'facilities': [{'id': 5, 'name': '免費停車位（數量有限）', 'is_popular': False},
#    {'id': 9, 'name': '行李寄放服務', 'is_popular': False},
#    {'id': 10, 'name': 'master刷卡服務', 'is_popular': False},
#    {'id': 11, 'name': 'visa刷卡服務', 'is_popular': False},
#    {'id': 12, 'name': '專人辦理入住/退房', 'is_popular': False},
#    {'id': 13, 'name': '電梯', 'is_popular': False},
#    {'id': 14, 'name': '公共區域免費上網', 'is_popular': False},
#    {'id': 16, 'name': '所有房型免費 Wi-Fi', 'is_popular': False},
#    {'id': 26, 'name': '中文', 'is_popular': False},
#    {'id': 27, 'name': '英文', 'is_popular': False},
#    {'id': 34, 'name': '附近有便利商店', 'is_popular': False},
#    {'id': 36, 'name': '禁菸飯店', 'is_popular': True},
#    {'id': 66, 'name': '可代收包裹', 'is_popular': True},
#    {'id': 80, 'name': '公共飲水機', 'is_popular': False},
#    {'id': 92, 'name': '煙霧偵測器', 'is_popular': False},
#    {'id': 39, 'name': '付費機場接送', 'is_popular': False},
#    {'id': 89, 'name': '急救箱', 'is_popular': False},
#    {'id': 90, 'name': '滅火器', 'is_popular': False},
#    {'id': 94, 'name': 'CCTV監視器', 'is_popular': False}],
#   'images': [{'title': 'title1',
#     'intro': 'intro1',
#     'url': 'http://image.pms.tw/image/hotel/65MbxhnduOrY6I4HT1G59E.jpg',
#     'ranking': 1},
#    {'title': 'title2',
#     'intro': 'intro2',
#     'url': 'http://image.pms.tw/image/hotel/65GIgbDnGOlRUIqmdpyj3a.jpg',
#     'ranking': 2},
#    {'title': 'title3',
#     'intro': 'intro3',
#     'url': 'http://image.pms.tw/image/hotel/65K84sJnkqXpFRqvYoS2U2.jpg',
#     'ranking': 3},
#    {'title': 'title4',
#     'intro': 'intro4',
#     'url': 'http://image.pms.tw/image/hotel/654iqTEEIcAbye90uTr84K.jpg',
#     'ranking': 4},
#    {'title': 'title5',
#     'intro': 'intro5',
#     'url': 'http://image.pms.tw/image/hotel/65ib8EKbXz7872rMJ3uddr.jpg',
#     'ranking': 5},
#    {'title': 'title6',
#     'intro': 'intro6',
#     'url': 'http://image.pms.tw/image/hotel/65Zg0qhoUtmNw8G47KDHe7.jpg',
#     'ranking': 6},
#    {'title': 'title7',
#     'intro': 'intro7',
#     'url': 'http://image.pms.tw/image/hotel/65iu7f0jbe4jvnfMIz0nSH.jpg',
#     'ranking': 7},
#    {'title': 'title8',
#     'intro': 'intro8',
#     'url': 'http://image.pms.tw/image/hotel/6503JmVcP6Gz0MEyUcNi3b.jpg',
#     'ranking': 8}]},
#  {'id': 38,
#   'status': 'OPEN',
#   'domain': 'guidehoteltbp',
#   'name': '雀客旅館台中文心中清',
#   'phone': '',
#   'meals': [1],
#   'url': 'https://www.mastripms.com/guidehoteltbp/view',
#   'check_in': '15:00:00',
#   'last_check_in': '23:59:00',
#   'check_out': '11:00:00',
#   'service_mail': 'reservation.service@dunqian.com',
#   'child_age': 12,
#   'address': '404台中市北區立人里北平路一段6號 No. 6, Sec. 1, Beiping Rd., North Dist., Taichung City 404, Taiwan (R.O.C.)',
#   'latitude': 24.17154,
#   'longitude': 120.66782,
#   'intro': '位於市中心的雀客旅館文心中清，機動性高的週遭機能，方便快速地前往各個知名景點。簡約舒適的大空間，搭配全館木地板的配置，是許多親子家庭及商務旅客的首選。\r\n現代時尚的裝潢風格，提供新穎創意的住宿體驗，旅人在充分放鬆之餘，也享有發現驚喜的樂趣。',
#   'cancel_policies': [{'start_days': None,
#     'end_days': 3,
#     'percent': 100,
#     'description': '不收取任何費用'},
#    {'start_days': 2, 'end_days': 1, 'percent': 50, 'description': '收取50%已付金額'},
#    {'start_days': 0,
#     'end_days': 0,
#     'percent': 0,
#     'description': '收取100%已付金額'}],
#   'notice': '►館內附設地下停車場，限高180公分，數量有限無法預約；如需相關資訊，請洽櫃台服務專線。\r\n\r\n1.館內全館禁菸，無提供寵物住宿，如有發現吸菸或攜帶寵物入住，將加收3000元清潔費，如有設備損壞乃需照價賠償。\r\n2.住宿房型依房間格局不同會有變化，照片僅供參考。\r\n3.貴重物品請隨身保管，或放置房內個人保險箱，若遺失本館不予負責。\r\n4.為維護住宿品質，夜間22:00後請降低音量，避免影響其他旅客權益。\r\n5.本館保留一切修改飯店注意事項之權利。\r\n►更多活動資訊請洽旅館官方網站或FB粉絲專頁。',
#   'cancel_notice': '【一般旅館適用】\r\n※第三方訂房平台或其他預訂管道，將不適用以下官網預訂取消政策。\r\n※完成預訂後，請確認是否收到訂房通知簡訊/信件，如需協助請致電訂房中心。\r\n※繳費期限為訂房後24小時，未於時效內使用點數或刷卡支付訂單30%款項，系統將自動取消訂單並釋出訂房，請貴賓重新操作訂房。\r\n※若會員點數未達訂金額度，請點選支付訂單全額；或點選支付訂金作業，完成刷卡後來電客服做點數折抵。\r\n※官網房價包含稅金及服務費，發票如有統編開立需求請於入住時提出，發票開立7日內僅提供一次更改，並請妥善留存紙本發票。\r\n\r\n依照觀光局訂房定型化契約規定，訂單成立後旅店將收取約定房費作為訂房擔保，旅客解除契約時，應通知業者，並得要求業者依下列基準處理：\r\n預先支付訂金者，將收取總房費30%，餘款將於入住首日支付。\r\n預訂取消規則如下：\r\n1. 旅客於約定住宿前3日通知取消者，可退款100%已付金額。\r\n2. 旅客於約定住宿前1-2日通知取消者，扣款已付金額50%後可申請退費。\r\n3. 旅客約定住宿當日通知取消或未如期入住者(no show)，應負擔100%已付金額為取消費用。\r\n4. 約定住宿抵達3日內，如需修改訂單內容，將依照取消規定比例收取費用。\r\n住房當日若遇氣象局發佈陸上颱風警報(旅客之出發地、抵達地、或是旅途必經途中任何一區位於公告之警戒區域)，於警報解除前可提供全數退款，亦可全額保留於申請日後一年內住房折抵使用。\r\n※款項保留者，如逾期未使用或訂房後未入住(no show)，將沒收保留全額款項不另行通知。\r\n※匯款退費之手續費由收款人負擔，不另提供出款證明，如需協助請洽客服中心。\r\n※退款作業需7-14天工作日，如遇例假日或國定假日將順延作業流程，還請貴賓耐心等候。\r\n\r\nHotel cancellation policy\r\n※ Third-party booking platforms (Online Travel Agent) does not apply to the cancellation policy on the official website.\r\n※ After completing the reservation, please confirm whether you have received the reservation notification SMS/letter. If you need assistance, please call the reservation center.\r\n※ Please pay the outstanding payment in 24hrs or your reservation will be cancelled automatically. If so, please reserve it again.\r\n※ The price on the official website includes taxes and service fees. \r\n\r\nIf there is a demand for tax ID of invoices, please put forward at the time of check-in. Only one change is provided within 7 days after the invoice is issued, and please properly keep the invoice.\r\n\r\nThose who pay the deposit in advance will be charged 30% of the total room charge, and the balance will be paid on the first day of stay.\r\nWhen the passenger rescinds the contract, he/she shall notify the operator, and may require the operator to handle according as below:\r\n1. Customers who notify the cancellation 3 days before the check-in date are entitled to a 100% refund of the room charge.\r\n2. Customers who notify cancellation 1-2 days before the check-in date can apply for refund after deducting 50% of the room charge.\r\n3. Customers who notify the cancellation or no show on the same day, the room charge is non-refundable.\r\n4. If you need to modify the order content within 3 days after the arrival date, you will be charged according to the cancellation ratio.\r\n\r\nIf an onshore typhoon warning is issued by the weather bureau on the check-in date, the full amount can be refunded before the warning is lifted, and the full amount can also be retained for next booking within one year of the application date.\r\n\r\n※ If the person who retains the money fails to use the room within the time limit or does not show the room after the reservation, the full amount of the money will be confiscated without further notice.\r\n※ The service charge for remittance refund shall be borne by the payee, and no proof of payment will be provided. If you need assistance, please contact the customer service center.\r\n※ Refund operation takes 7-14 working days. In case of a holiday or a national holiday, the operation process will be postponed. Please wait patiently.',
#   'booking_notice': '【一般旅館適用】\r\n►入住時間為15:00後；退房時間：中午11:00以前。\r\n►辦理入住時，請備妥入住人身分證件以便進行登記。\r\n館內採自助機台入住報到，欲使用觀光局自由行紙本票卷或第三方實體住宿卷折抵，請洽櫃台人員協助，如有任何需求亦可使用自助機台旁黑色電話聯繫客服為您服務。\r\n\r\n1.如有提早入住或延後退房需求將酌收額外費用，請於預訂時告知客服或櫃台人員辦理登記，相關費用將依平假日/連續假期等浮動調整。\r\n2.館內全館禁菸，無提供寵物住宿，如有發現吸菸或攜帶寵物入住，將加收3000元清潔費，如有設備損壞乃需照價賠償。\r\n3.相關訂房住宿規範，依本館公告為主，如有疑問請於【訂房/繳費】前來電洽詢。\r\n4.相關退訂政策請參閱【取消訂房須知】。\r\n5.官網房型售價不包含加人、加床費用，如需協助請另洽訂房中心。\r\n6.館內提供雙人及四人房型，超過房型指定人數且6歲(含)以上，將加收加人(含備品)費用，請洽訂房中心安排。\r\n►加人800元/人(含備品)\r\n►每房提供1位0-5歲孩童免費同住，如超過前述入住人數，將收取1位加人費用。\r\n連續及特殊假期日將依照政府行政機關辦公日曆表公告\r\n7.官網訂房售價已含服務費及營業稅，本館保留一切修改訂房須知之權利。\r\n8.預訂完成後，請於24小時內完成款項支付，第三方訂房平台之訂單請參照平台訂房規定。',
#   'country': {'name': '臺灣'},
#   'province': {'name': '台灣省'},
#   'county': {'name': '臺中市'},
#   'district': {'name': '北區'},
#   'facilities': [{'id': 1, 'name': '24小時接待入住', 'is_popular': True},
#    {'id': 3, 'name': '24小時櫃檯服務', 'is_popular': False},
#    {'id': 10, 'name': 'master刷卡服務', 'is_popular': False},
#    {'id': 11, 'name': 'visa刷卡服務', 'is_popular': False},
#    {'id': 13, 'name': '電梯', 'is_popular': False},
#    {'id': 16, 'name': '所有房型免費 Wi-Fi', 'is_popular': False},
#    {'id': 26, 'name': '中文', 'is_popular': False},
#    {'id': 27, 'name': '英文', 'is_popular': False},
#    {'id': 86, 'name': '房客入住前客房消毒', 'is_popular': False},
#    {'id': 89, 'name': '急救箱', 'is_popular': False},
#    {'id': 90, 'name': '滅火器', 'is_popular': False},
#    {'id': 5, 'name': '免費停車位（數量有限）', 'is_popular': False},
#    {'id': 34, 'name': '附近有便利商店', 'is_popular': False},
#    {'id': 36, 'name': '禁菸飯店', 'is_popular': True},
#    {'id': 39, 'name': '付費機場接送', 'is_popular': False},
#    {'id': 51, 'name': '會議室', 'is_popular': False},
#    {'id': 73, 'name': '電子支付服務', 'is_popular': False},
#    {'id': 84, 'name': '每日清潔消毒', 'is_popular': False},
#    {'id': 87, 'name': '房客及員工體溫測量', 'is_popular': False},
#    {'id': 88, 'name': '員工佩戴口罩與面罩', 'is_popular': False},
#    {'id': 91, 'name': '灑水設備', 'is_popular': False},
#    {'id': 92, 'name': '煙霧偵測器', 'is_popular': False},
#    {'id': 94, 'name': 'CCTV監視器', 'is_popular': False}],
#   'images': [{'title': 'title1',
#     'intro': 'intro1',
#     'url': 'http://image.pms.tw/image/hotel/432PATnNzqG0QE4sGiURDKF.jpg',
#     'ranking': 1},
#    {'title': 'title2',
#     'intro': 'intro2',
#     'url': 'http://image.pms.tw/image/hotel/432CcwgPzxVkHnYJQ2F4PyY.jpg',
#     'ranking': 2},
#    {'title': 'title3',
#     'intro': 'intro3',
#     'url': 'http://image.pms.tw/image/hotel/432FoOz01mXnDFKMOZCYCVO.jpg',
#     'ranking': 3},
#    {'title': 'title4',
#     'intro': 'intro4',
#     'url': 'http://image.pms.tw/image/hotel/432ahjxmsw9ilg9LHgLSpxp.jpg',
#     'ranking': 4},
#    {'title': 'title5',
#     'intro': 'intro5',
#     'url': 'http://image.pms.tw/image/hotel/432iiEK0NQ5HvlE7cKSiX1s.jpg',
#     'ranking': 5},
#    {'title': 'title6',
#     'intro': 'intro6',
#     'url': 'http://image.pms.tw/image/hotel/432rYUOujO0fPbGkA6jsv12.jpg',
#     'ranking': 6}]},
#  {'id': 37,
#   'status': 'OPEN',
#   'domain': 'parkhotel',
#   'name': '承攜行旅中壢中正館',
#   'phone': '4266 628',
#   'meals': [1],
#   'url': 'https://www.mastripms.com/parkhotel/view',
#   'check_in': '15:00:00',
#   'last_check_in': '23:59:00',
#   'check_out': '11:00:00',
#   'service_mail': 'reservation.service@dunqian.com',
#   'child_age': 12,
#   'address': '320桃園市中壢區中正路51號 No. 51, Zhongzheng Rd., Zhongli Dist., Taoyuan City 320, Taiwan (R.O.C.)',
#   'latitude': 24.95413,
#   'longitude': 121.22451,
#   'intro': '承攜行旅中壢中正館位於中壢火車站精華商圈，交通便利、生活機能佳，無論是洽公商旅或是旅遊規劃，絕對是最佳的選擇。\r\n踏入大廳，映入眼簾的是精心設計的日式庭園造景，房內採簡約設計風格，空間寬敞宜人，提供旅客愜意舒適的住宿環境。',
#   'cancel_policies': [{'start_days': None,
#     'end_days': 3,
#     'percent': 100,
#     'description': '不收取任何費用'},
#    {'start_days': 2, 'end_days': 1, 'percent': 50, 'description': '收取50%已付金額'},
#    {'start_days': 0,
#     'end_days': 0,
#     'percent': 0,
#     'description': '收取100%已付金額'}],
# ...
#    {'id': 44, 'name': '酒吧', 'is_popular': False},
#    {'id': 45, 'name': '健康步道', 'is_popular': False},
#    {'id': 46, 'name': '電動遊戲室', 'is_popular': False},
#    {'id': 47, 'name': '禮品店', 'is_popular': False},
#    {'id': 48, 'name': '咖啡廳', 'is_popular': False},
#    {'id': 49, 'name': '電影院', 'is_popular': False},
#    {'id': 50, 'name': '商務中心', 'is_popular': False},
#    {'id': 51, 'name': '會議室', 'is_popular': False},
#    {'id': 52, 'name': '傳真機', 'is_popular': False},
#    {'id': 53, 'name': '免費報紙', 'is_popular': False},
#    {'id': 54, 'name': '郵寄服務', 'is_popular': False},
#    {'id': 55, 'name': '印表機', 'is_popular': False},
#    {'id': 56, 'name': '代客叫車服務', 'is_popular': False},
#    {'id': 57, 'name': '保險箱租借', 'is_popular': False},
#    {'id': 58, 'name': '開放式廚房', 'is_popular': False},
#    {'id': 59, 'name': '烤箱', 'is_popular': False},
#    {'id': 60, 'name': '露台', 'is_popular': False},
#    {'id': 61, 'name': '醫務室', 'is_popular': False},
#    {'id': 62, 'name': '寄物櫃', 'is_popular': False},
#    {'id': 63, 'name': '宴會廳', 'is_popular': False},
#    {'id': 64, 'name': '婚宴服務', 'is_popular': False},
#    {'id': 65, 'name': '交誼廳', 'is_popular': False},
#    {'id': 66, 'name': '可代收包裹', 'is_popular': True},
#    {'id': 67, 'name': '圖書館', 'is_popular': False},
#    {'id': 68, 'name': '森林浴', 'is_popular': False},
#    {'id': 69, 'name': '可代收外送', 'is_popular': True},
#    {'id': 70, 'name': '3C週邊租借', 'is_popular': True},
#    {'id': 71, 'name': '票券代售服務', 'is_popular': False},
#    {'id': 72, 'name': 'Morning call服務', 'is_popular': False},
#    {'id': 73, 'name': '電子支付服務', 'is_popular': False},
#    {'id': 74, 'name': '攜帶型 WiFi 租借', 'is_popular': False},
#    {'id': 75, 'name': '娛樂設備租借', 'is_popular': True},
#    {'id': 76, 'name': '美容服務', 'is_popular': False},
#    {'id': 77, 'name': 'SPA按摩服務', 'is_popular': False},
#    {'id': 78, 'name': '按摩椅', 'is_popular': False},
#    {'id': 79, 'name': '免費迎賓茶點', 'is_popular': False},
#    {'id': 80, 'name': '公共飲水機', 'is_popular': False},
#    {'id': 81, 'name': '有吸菸客房', 'is_popular': False},
#    {'id': 82, 'name': None, 'is_popular': False},
#    {'id': 83, 'name': '電動車充電站', 'is_popular': False},
#    {'id': 84, 'name': '每日清潔消毒', 'is_popular': False},
#    {'id': 85, 'name': '每日房外收取垃圾', 'is_popular': False},
#    {'id': 86, 'name': '房客入住前客房消毒', 'is_popular': False},
#    {'id': 87, 'name': '房客及員工體溫測量', 'is_popular': False},
#    {'id': 88, 'name': '員工佩戴口罩與面罩', 'is_popular': False},
#    {'id': 89, 'name': '急救箱', 'is_popular': False},
#    {'id': 90, 'name': '滅火器', 'is_popular': False},
#    {'id': 91, 'name': '灑水設備', 'is_popular': False},
#    {'id': 92, 'name': '煙霧偵測器', 'is_popular': False},
#    {'id': 93, 'name': '一氧化碳偵測器', 'is_popular': False},
#    {'id': 94, 'name': 'CCTV監視器', 'is_popular': False},
#    {'id': 95, 'name': 'AED心臟去顫器', 'is_popular': False}],
#   'images': [{'title': 'title1',
#     'intro': 'intro1',
#     'url': 'http://image.pms.tw/image/hotel/1049ldt7aUUhONSlaG2j8kWq.png',
#     'ranking': 1},
#    {'title': 'title2',
#     'intro': 'intro2',
#     'url': 'http://image.pms.tw/image/hotel/1049KwuDQZS3GwwbQwK9Td4D.png',
#     'ranking': 2},
#    {'title': 'title3',
#     'intro': 'intro3',
#     'url': 'http://image.pms.tw/image/hotel/10490ftIgwas6prZa3yvnTpe.gif',
#     'ranking': 3}]},
#  {'id': 1,
#   'status': 'OPEN',
#   'domain': 'partner',
#   'name': 'Partner飯店',
#   'phone': '0912 345 679',
#   'meals': [1],
#   'url': 'https://www.mastripms.com/partner/view',
#   'check_in': '05:02:00',
#   'last_check_in': '01:30:00',
#   'check_out': '07:00:00',
#   'service_mail': 'ivan.shi@dunqian.tw',
#   'child_age': 6,
#   'address': '黎明路3段384號6F之一104Ex.',
#   'latitude': 24.18224424,
#   'longitude': 120.63898841,
#   'intro': 'test 飯店介紹詞',
#   'cancel_policies': [{'start_days': None,
#     'end_days': 7,
#     'percent': 100,
#     'description': '不收取任何費用'},
#    {'start_days': 6, 'end_days': 4, 'percent': 50, 'description': '收取50%已付金額'},
#    {'start_days': 3,
#     'end_days': 0,
#     'percent': 0,
#     'description': '收取100%已付金額'}],
#   'notice': '【飯店注意事項】請輸入飯店注意事項(輸入字數限3000字以內)--00002',
#   'cancel_notice': '退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店退訂取消規定(輸入字數限6000字以內)退訂取消規定 請輸入飯店 ...
#   'booking_notice': '【訂房須知】訂購房間需加購套餐組--00001',
#   'country': {'name': '臺灣'},
#   'province': {'name': '台灣省'},
#   'county': {'name': '新北市'},
#   'district': {'name': '烏來區'},
#   'facilities': [{'id': 1, 'name': '24小時接待入住', 'is_popular': True},
#    {'id': 2, 'name': '24小時保全', 'is_popular': False},
#    {'id': 3, 'name': '24小時櫃檯服務', 'is_popular': False},
#    {'id': 4, 'name': '24小時送餐服務', 'is_popular': False},
#    {'id': 5, 'name': '免費停車位（數量有限）', 'is_popular': False},
#    {'id': 6, 'name': '停車位事先預約', 'is_popular': False},
#    {'id': 7, 'name': '付費停車位', 'is_popular': False},
#    {'id': 8, 'name': '無障礙設施', 'is_popular': False},
#    {'id': 9, 'name': '行李寄放服務', 'is_popular': False},
#    {'id': 10, 'name': 'master刷卡服務', 'is_popular': False},
#    {'id': 11, 'name': 'visa刷卡服務', 'is_popular': False},
#    {'id': 12, 'name': '專人辦理入住/退房', 'is_popular': False},
#    {'id': 13, 'name': '電梯', 'is_popular': False},
#    {'id': 14, 'name': '公共區域免費上網', 'is_popular': False},
#    {'id': 15, 'name': '付費上網服務', 'is_popular': False},
#    {'id': 16, 'name': '所有房型免費 Wi-Fi', 'is_popular': False},
#    {'id': 17, 'name': '衣物送洗服務', 'is_popular': True},
#    {'id': 18, 'name': '健身房', 'is_popular': False},
#    {'id': 19, 'name': '蒸氣室', 'is_popular': False},
#    {'id': 20, 'name': '餐廳', 'is_popular': False},
#    {'id': 21, 'name': '烤肉區', 'is_popular': False},
#    {'id': 22, 'name': '溫泉', 'is_popular': False},
#    {'id': 23, 'name': '卡拉ＯＫ', 'is_popular': False},
#    {'id': 24, 'name': '三溫暖', 'is_popular': False},
#    {'id': 25, 'name': '美髮服務', 'is_popular': False},
#    {'id': 26, 'name': '中文', 'is_popular': False},
#    {'id': 27, 'name': '英文', 'is_popular': False},
#    {'id': 28, 'name': '日文', 'is_popular': False},
#    {'id': 29, 'name': '韓文', 'is_popular': False},
#    {'id': 30, 'name': '客房餐飲服務', 'is_popular': False},
#    {'id': 31, 'name': '值班管家服務', 'is_popular': False},
#    {'id': 32, 'name': '外幣兌換', 'is_popular': False},
#    {'id': 33, 'name': '自動提款機', 'is_popular': False},
#    {'id': 34, 'name': '附近有便利商店', 'is_popular': False},
#    {'id': 35, 'name': '自行車租借', 'is_popular': False},
#    {'id': 36, 'name': '禁菸飯店', 'is_popular': True},
#    {'id': 37, 'name': '吸菸區', 'is_popular': False},
#    {'id': 38, 'name': '包車旅遊行程', 'is_popular': False},
#    {'id': 39, 'name': '付費機場接送', 'is_popular': False},
#    {'id': 40, 'name': '免費機場接送', 'is_popular': False},
#    {'id': 41, 'name': '旅遊諮詢', 'is_popular': False},
#    {'id': 42, 'name': '室內游泳池', 'is_popular': False},
#    {'id': 43, 'name': '戶外游泳池', 'is_popular': False},
#    {'id': 44, 'name': '酒吧', 'is_popular': False},
#    {'id': 45, 'name': '健康步道', 'is_popular': False},
#    {'id': 46, 'name': '電動遊戲室', 'is_popular': False},
#    {'id': 47, 'name': '禮品店', 'is_popular': False},
#    {'id': 48, 'name': '咖啡廳', 'is_popular': False},
#    {'id': 49, 'name': '電影院', 'is_popular': False},
#    {'id': 50, 'name': '商務中心', 'is_popular': False},
#    {'id': 51, 'name': '會議室', 'is_popular': False},
#    {'id': 52, 'name': '傳真機', 'is_popular': False},
#    {'id': 53, 'name': '免費報紙', 'is_popular': False},
#    {'id': 54, 'name': '郵寄服務', 'is_popular': False},
#    {'id': 55, 'name': '印表機', 'is_popular': False},
#    {'id': 56, 'name': '代客叫車服務', 'is_popular': False},
#    {'id': 57, 'name': '保險箱租借', 'is_popular': False},
#    {'id': 58, 'name': '開放式廚房', 'is_popular': False},
#    {'id': 59, 'name': '烤箱', 'is_popular': False},
#    {'id': 60, 'name': '露台', 'is_popular': False},
#    {'id': 61, 'name': '醫務室', 'is_popular': False},
#    {'id': 62, 'name': '寄物櫃', 'is_popular': False},
#    {'id': 63, 'name': '宴會廳', 'is_popular': False},
#    {'id': 64, 'name': '婚宴服務', 'is_popular': False},
#    {'id': 65, 'name': '交誼廳', 'is_popular': False},
#    {'id': 66, 'name': '可代收包裹', 'is_popular': True},
#    {'id': 67, 'name': '圖書館', 'is_popular': False},
#    {'id': 68, 'name': '森林浴', 'is_popular': False},
#    {'id': 69, 'name': '可代收外送', 'is_popular': True},
#    {'id': 70, 'name': '3C週邊租借', 'is_popular': True},
#    {'id': 71, 'name': '票券代售服務', 'is_popular': False},
#    {'id': 72, 'name': 'Morning call服務', 'is_popular': False},
#    {'id': 73, 'name': '電子支付服務', 'is_popular': False},
#    {'id': 74, 'name': '攜帶型 WiFi 租借', 'is_popular': False},
#    {'id': 75, 'name': '娛樂設備租借', 'is_popular': True},
#    {'id': 76, 'name': '美容服務', 'is_popular': False},
#    {'id': 77, 'name': 'SPA按摩服務', 'is_popular': False},
#    {'id': 78, 'name': '按摩椅', 'is_popular': False},
#    {'id': 79, 'name': '免費迎賓茶點', 'is_popular': False},
#    {'id': 80, 'name': '公共飲水機', 'is_popular': False},
#    {'id': 81, 'name': '有吸菸客房', 'is_popular': False},
#    {'id': 82, 'name': None, 'is_popular': False},
#    {'id': 83, 'name': '電動車充電站', 'is_popular': False},
#    {'id': 84, 'name': '每日清潔消毒', 'is_popular': False},
#    {'id': 85, 'name': '每日房外收取垃圾', 'is_popular': False},
#    {'id': 86, 'name': '房客入住前客房消毒', 'is_popular': False},
#    {'id': 87, 'name': '房客及員工體溫測量', 'is_popular': False},
#    {'id': 88, 'name': '員工佩戴口罩與面罩', 'is_popular': False},
#    {'id': 89, 'name': '急救箱', 'is_popular': False},
#    {'id': 91, 'name': '灑水設備', 'is_popular': False},
#    {'id': 92, 'name': '煙霧偵測器', 'is_popular': False},
#    {'id': 93, 'name': '一氧化碳偵測器', 'is_popular': False},
#    {'id': 95, 'name': 'AED心臟去顫器', 'is_popular': False}],
#   'images': [{'title': 'title1',
#     'intro': 'intro1',
#     'url': 'http://image.pms.tw/image/hotel/1Wc0Kkis1HbWrXMpsEHN0.jpeg',
#     'ranking': 1},
#    {'title': 'title2',
#     'intro': 'intro2',
#     'url': 'http://image.pms.tw/image/hotel/1bXG65HAj9lDG68CiIOci.jpeg',
#     'ranking': 2},
#    {'title': 'title3',
#     'intro': 'intro3',
#     'url': 'http://image.pms.tw/image/hotel/1pMRYbskXXnZBDUKuxfJ8.jpeg',
#     'ranking': 3},
#    {'title': 'title4',
#     'intro': 'intro4',
#     'url': 'http://image.pms.tw/image/hotel/1PYeTI4MkcvdYzr7Iil7V.png',
#     'ranking': 4},
#    {'title': 'title5',
#     'intro': 'intro5',
#     'url': 'http://image.pms.tw/image/hotel/1NcktxHaqZdVdqi4dz5bC.png',
#     'ranking': 5},
#    {'title': 'title6',
#     'intro': 'intro6',
#     'url': 'http://image.pms.tw/image/hotel/1tyLHpRdaHtjXFnyLzRWj.png',
#     'ranking': 6},
#    {'title': 'title7',
#     'intro': 'intro7',
#     'url': 'http://image.pms.tw/image/hotel/1ylyOZQexDd9TJUJi2tlE.png',
#     'ranking': 7},
#    {'title': 'title8',
#     'intro': 'intro8',
#     'url': 'http://image.pms.tw/image/hotel/1pxJhi2C7o7W0W91kCz4v.png',
#     'ranking': 8},
#    {'title': 'title9',
#     'intro': 'intro9',
#     'url': 'http://image.pms.tw/image/hotel/1RRQ2ExAD1GeJxaWqdJGO.png',
#     'ranking': 9},
#    {'title': 'title10',
#     'intro': 'intro10',
#     'url': 'http://image.pms.tw/image/hotel/1Jlhsk2uu3IEcD2gea6lg.jpg',
#     'ranking': 10},
#    {'title': 'title11',
#     'intro': 'intro11',
#     'url': 'http://image.pms.tw/image/hotel/1DsLWWckfzaTjgtpErTSH.png',
#     'ranking': 11},
#    {'title': 'title12',
#     'intro': 'intro12',
#     'url': 'http://image.pms.tw/image/hotel/1paNKiLoeVF0Liz1k9x7p.png',
#     'ranking': 12},
#    {'title': 'title13',
#     'intro': 'intro13',
#     'url': 'http://image.pms.tw/image/hotel/1ITURDfsOZx1EZqlGJZYN.png',
#     'ranking': 13},
#    {'title': 'title14',
#     'intro': 'intro14',
#     'url': 'http://image.pms.tw/image/hotel/17POlM1gfc8qAWHOaKYMS.jpg',
#     'ranking': 14},
#    {'title': 'title15',
#     'intro': 'intro15',
#     'url': 'http://image.pms.tw/image/hotel/1FV7qHRKhgh9fPYK39KL2.jpg',
#     'ranking': 15},
#    {'title': 'title16',
#     'intro': 'intro16',
#     'url': 'http://image.pms.tw/image/hotel/13VoElMO0LkDmrJg1F0I8.jpg',
#     'ranking': 16},
#    {'title': 'title17',
#     'intro': 'intro17',
#     'url': 'http://image.pms.tw/image/hotel/1qyUWfeDNwmtqg8EvbaLU.jpg',
#     'ranking': 17},
#    {'title': 'title18',
#     'intro': 'intro18',
#     'url': 'http://image.pms.tw/image/hotel/1uBMrNo162pzKjDiw7C8u.png',
#     'ranking': 18},
#    {'title': 'title19',
#     'intro': 'intro19',
#     'url': 'http://image.pms.tw/image/hotel/1ZiZMK4CIADOtFKqgaA79.png',
#     'ranking': 19},
#    {'title': 'title20',
#     'intro': 'intro20',
#     'url': 'http://image.pms.tw/image/hotel/15eCWWMsd8HdNvl65ww4S.png',
#     'ranking': 20},
#    {'title': 'title21',
#     'intro': 'intro21',
#     'url': 'http://image.pms.tw/image/hotel/1GK2svXRRdA0J9QzQPIPG.png',
#     'ranking': 21}]}]

# %%
response.json()
len()
